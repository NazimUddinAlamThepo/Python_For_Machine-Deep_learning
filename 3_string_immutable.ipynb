# %%
# multi line string

message = """  Tell me about youself ?
what are the issues you've facing while learning the code ?

"""
print(message)
# Out:
#   Tell me about youself ?
# what are the issues you've facing while learning the code ?

# %% [markdown]
# ### Indexing

# %%
message[4]
# Out:
# 'l'

# %% [markdown]
# ### Slicing  string_name [start : end : step]

# %%
m = message[0:30:2]
print(m)
# Out:
#  Tl eaotyuef?wa

# %%
print(message[-1])
print(message[-3])
# Out:
# ?

# %%
print(repr(message[-1]))
print(repr(message[-2]))
# Out:
# '\n'
# '\n'

# %% [markdown]
# ### String methods

# %%
string  = "Welcome to Phitron ML Course , Phitron ML , Hello ML" 

processed_string = string.lower()

# Just at the first word will be capitalize
processed_string = string.capitalize()

# length 
print(len(string))
print(processed_string)
# Out:
# 52
# Welcome to phitron ml course , phitron ml , hello ml

# %%
# word ase kina -> bool
print("phitron" in processed_string)

# shurur kon index theke substring ta shuru hoise 
shuru_index = processed_string.find("phitron")

# shesher dike kon index theke substring ta shuru hoise 
shesh_index = processed_string.rfind("phitron")


# Substring koibar ase 
count = processed_string.count("phitron")


# replace a substring 
processed_string = string.replace("ML", "AI/ML")


print(processed_string)
# Out:
# True
# Welcome to Phitron AI/ML Course , Phitron AI/ML , Hello AI/ML

# %% [markdown]
# ###
# Splitting , Joining , Formatted String

# %%
prompt = "what is Phitron ?"

tokens = prompt.split()
print(tokens)
print(type(tokens))
# Out:
# ['what', 'is', 'Phitron', '?']
# <class 'list'>

# %%
prompt = "what,is,Phitron ?"

tokens = prompt.split(',')
print(tokens)
print(type(tokens))
# Out:
# ['what', 'is', 'Phitron ?']
# <class 'list'>

# %%
sentence = "-".join(tokens)
print(sentence)
print(type(sentence))
# Out:
# what-is-Phitron ?
# <class 'str'>

# %% [markdown]
# ### formatted string

# %%
name = "Adil" 
age = 23 
height = 5.1123445

info = f"His name is {name.upper()}. He is {age} years old. He is {height:.3} feet tall.\n"



model_accuracy = 0.83333 

print(f"the model accuracy is {model_accuracy}")
# Out:
# the model accuracy is 0.83333
