# %%
s = {1,2,3,4}
s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 s = {1,2,3,4}
# ----> 2 s[1]
#
# TypeError: 'set' object is not subscriptable

# %%
s_iter = iter(s)
type(s_iter)
# Out:
# set_iterator

# %%
s = {1,2,3,4}

s_iter = iter(s)

print(next(s_iter))
print(next(s_iter))
print(next(s_iter))
print(next(s_iter))

# arekbar dile error khabo
# Out:
# 1
# 2
# 3
# 4
