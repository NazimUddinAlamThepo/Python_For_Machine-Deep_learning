# %% [markdown]
# ### For loop

# %%
for i in range(10):
    print(f"_{i}")
# Out:
# _0
# _1
# _2
# _3
# _4
# _5
# _6
# _7
# _8
# _9

# %%
for i in range(1 ,10):
    print(f"_{i}")
# Out:
# _1
# _2
# _3
# _4
# _5
# _6
# _7
# _8
# _9

# %%
for i in range(1,10,2):
    print(f"_{i}")
# Out:
# _1
# _3
# _5
# _7
# _9

# %% [markdown]
# ### While loop

# %%
count  = 1

while count<10:
    print(f"_{count}")
    count += 1
# Out:
# _1
# _2
# _3
# _4
# _5
# _6
# _7
# _8
# _9

# %%
# Out:
# 1
# <class 'str'>
