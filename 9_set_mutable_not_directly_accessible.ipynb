# %% [markdown]
# ### unodered -> so indexing and slicing capacity doesn't exist

# %%
A = { 1, 2 , 3 } 

print(type(A) , A )
# Out:
# <class 'set'> {1, 2, 3}

# %%
## empty structures 
B = [] 
print(type(B)) 

C= () 
print(type(C))


S = set()
print(type(S))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
#accessing 

S= { 1 ,2 ,3 , 4 ,1 ,2 } 

if (10 in S):
    print("3 is present")
else:
    print("not present")

sum =0 

for element in S:
    sum+= element 

print(sum)
# Out:
# not present
# 10
