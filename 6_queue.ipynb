# %%
queue = []

# insertion
queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)


#remove 
print(queue.pop(0))


# accessing the front element 

print(f"front e {queue[0]}")

queue.pop(0)

print(f"front e {queue[0]}")
# Out:
# 1
# front e 2
# front e 3
