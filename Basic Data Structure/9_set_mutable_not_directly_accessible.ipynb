# %% [markdown]
# ### unodered -> so indexing and slicing capacity doesn't exist

# %%
A = { 1, 2 , 3 } 

print(type(A) , A )
# Out:
# <class 'set'> {1, 2, 3}

# %%
## empty structures 
B = [] 
print(type(B)) 

C= () 
print(type(C))


S = set()
print(type(S))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
#accessing 

S= { 1 ,2 ,3 , 4 ,1 ,2 } 

if (10 in S):
    print("3 is present")
else:
    print("not present")

sum =0 

for element in S:
    sum+= element 

print(sum)
# Out:
# not present
# 10

# %%
# unordered proof (sorted hoye jabe)

S= {1,2,3,6,3,4,5,5}
print(S)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#mutable

s= {5, 1 , 2 ,4, 3} 

s.add(10) 
s.add(0)

print(s)

s.pop()
s.pop()
print(s)

s.remove(5) 

print(s)
# Out:
# {0, 1, 2, 3, 4, 5, 10}
# {2, 3, 4, 5, 10}
# {2, 3, 4, 10}

# %% [markdown]
# ### Methods

# %%
A = {1,2,3,4}
B = {1,2,3,4,5,6}

# mathematical 

print(A.union(B))
print(A.intersection(B))


# Disjoint 
print(A.isdisjoint(B))

#Subset
print(A.issubset(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4}
# False
# True
